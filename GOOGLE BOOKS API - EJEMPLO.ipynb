# %%
#abrimos la librerias que necesitamos
import requests
import json

# %% [raw]
# Seguimos....

# %%
#Obtenemos la api quedeseamos consultar, en este caso es google apis
result = requests.get("https://www.googleapis.com/books/v1/volumes?q=el+caballero+carmelo")
print(result.text) #Imprimimos la que contiene esta para poder analizarla
# Out:
# {
#   "kind": "books#volumes",
#   "totalItems": 1308,
#   "items": [
#     {
#       "kind": "books#volume",
#       "id": "6RNNAgAAQBAJ",
#       "etag": "IDoUCQBdK7w",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/6RNNAgAAQBAJ",
#       "volumeInfo": {
#         "title": "El Caballero Carmelo y otros cuentos",
#         "subtitle": "",
#         "authors": [
#           "Abraham Valdelomar"
#         ],
#         "publisher": "eLibros Editorial",
#         "publishedDate": "2011-09-15",
#         "description": "El Caballero Carmelo, colección de cuatro cuentos de Abraham Valdelomar publicada en 1918, se nos muestra tan rica y diversa que en cada uno de los relatos nos sumergimos en tonos narrativos diferentes, a veces opuestos, todos de una emotividad sorprendente. Iniciando por el suspenso desde la óptica de un niño que asiste, en una narración emocionante, al combate a muerte de su gallo; la melancolía y el ridículo, al mismo tiempo, de la historia de un triste hombre que tiene en un árbol del mismo nombre y edad a su alma gemela; la ternura y el drama del amor de un niño por su amiguita la estrella del circo; e incluso, nuevamente desde el punto de vista de un asustado chico –miedo en el que el lector también se involucra– que presencia apariciones de una mujer extraña, una especie de visión muy personal de lo religioso. Todo lo anterior nos da como resultado un libro ágil y que rompe por su sencillez de estilo y temática con la moda literaria precedente, tan española y artificial. Esta edición incluye biografía del autor y prefacio con contexto histórico y literario de la obra.",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9789588732237"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "9588732239"
#           }
#         ],
#         "readingModes": {
#           "text": true,
#           "image": false
#         },
#         "pageCount": 96,
#         "printType": "BOOK",
#         "categories": [
#           "Fiction"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": true,
#         "contentVersion": "preview-1.0.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=6RNNAgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=6RNNAgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "es",
#         "previewLink": "http://books.google.com.pe/books?id=6RNNAgAAQBAJ&printsec=frontcover&dq=el+caballero+carmelo&hl=&cd=1&source=gbs_api",
#         "infoLink": "https://play.google.com/store/books/details?id=6RNNAgAAQBAJ&source=gbs_api",
#         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=6RNNAgAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "PE",
#         "saleability": "FOR_SALE",
#         "isEbook": true,
#         "listPrice": {
#           "amount": 7.87,
#           "currencyCode": "PEN"
#         },
#         "retailPrice": {
#           "amount": 7.87,
#           "currencyCode": "PEN"
#         },
#         "buyLink": "https://play.google.com/store/books/details?id=6RNNAgAAQBAJ&rdid=book-6RNNAgAAQBAJ&rdot=1&source=gbs_api",
#         "offers": [
#           {
#             "finskyOfferType": 1,
#             "listPrice": {
#               "amountInMicros": 7870000,
#               "currencyCode": "PEN"
#             },
#             "retailPrice": {
#               "amountInMicros": 7870000,
#               "currencyCode": "PEN"
#             }
#           }
#         ]
#       },
#       "accessInfo": {
#         "country": "PE",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.com.pe/books/download/El_Caballero_Carmelo_y_otros_cuentos-sample-epub.acsm?id=6RNNAgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=6RNNAgAAQBAJ&hl=&printsec=frontcover&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "El Caballero Carmelo, colección de cuatro cuentos de Abraham Valdelomar publicada en 1918, se nos muestra tan rica y diversa que en cada uno de los relatos nos sumergimos en tonos narrativos diferentes, a veces opuestos, todos de una ..."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "YTw2AAAAIAAJ",
#       "etag": "eB9W9v4tmLI",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/YTw2AAAAIAAJ",
#       "volumeInfo": {
#         "title": "Perfil y entraña de El caballero Carmelo",
#         "subtitle": "el arte del cuento criollo",
#         "authors": [
#           "Armando F. Zubizarreta"
#         ],
#         "publishedDate": "1968",
#         "industryIdentifiers": [
#           {
#             "type": "OTHER",
#             "identifier": "UCAL:B3600248"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 199,
#         "printType": "BOOK",
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "1.5.4.0.preview.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=YTw2AAAAIAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=YTw2AAAAIAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "es",
#         "previewLink": "http://books.google.com.pe/books?id=YTw2AAAAIAAJ&q=el+caballero+carmelo&dq=el+caballero+carmelo&hl=&cd=2&source=gbs_api",
#         "infoLink": "http://books.google.com.pe/books?id=YTw2AAAAIAAJ&dq=el+caballero+carmelo&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Perfil_y_entra%C3%B1a_de_El_caballero_Carmel.html?hl=&id=YTw2AAAAIAAJ"
#       },
#       "saleInfo": {
#         "country": "PE",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "PE",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=YTw2AAAAIAAJ&hl=&printsec=frontcover&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "-2saAQAAMAAJ",
#       "etag": "b9GxZ8Eo/6Y",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/-2saAQAAMAAJ",
#       "volumeInfo": {
#         "title": "El caballero Carmelo",
#         "authors": [
#           "Abraham Valdelomar"
#         ],
#         "publishedDate": "1989",
#         "industryIdentifiers": [
#           {
#             "type": "OTHER",
#             "identifier": "IND:39000004694720"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 122,
#         "printType": "BOOK",
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "0.0.1.0.preview.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=-2saAQAAMAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=-2saAQAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "es",
#         "previewLink": "http://books.google.com.pe/books?id=-2saAQAAMAAJ&q=el+caballero+carmelo&dq=el+caballero+carmelo&hl=&cd=3&source=gbs_api",
#         "infoLink": "http://books.google.com.pe/books?id=-2saAQAAMAAJ&dq=el+caballero+carmelo&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/El_caballero_Carmelo.html?hl=&id=-2saAQAAMAAJ"
#       },
#       "saleInfo": {
#         "country": "PE",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "PE",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=-2saAQAAMAAJ&hl=&printsec=frontcover&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "3CRCAAAAYAAJ",
#       "etag": "27GM6Zh2f+c",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/3CRCAAAAYAAJ",
#       "volumeInfo": {
#         "title": "La ciudad de los tísicos",
#         "subtitle": "El caballero Carmelo y otros cuentos",
#         "authors": [
#           "Abraham Valdelomar"
#         ],
#         "publishedDate": "1973",
#         "industryIdentifiers": [
#           {
#             "type": "OTHER",
#             "identifier": "UTEXAS:059173024295151"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 153,
#         "printType": "BOOK",
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "0.0.2.0.preview.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=3CRCAAAAYAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=3CRCAAAAYAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "es",
#         "previewLink": "http://books.google.com.pe/books?id=3CRCAAAAYAAJ&q=el+caballero+carmelo&dq=el+caballero+carmelo&hl=&cd=4&source=gbs_api",
#         "infoLink": "http://books.google.com.pe/books?id=3CRCAAAAYAAJ&dq=el+caballero+carmelo&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/La_ciudad_de_los_t%C3%ADsicos.html?hl=&id=3CRCAAAAYAAJ"
#       },
#       "saleInfo": {
#         "country": "PE",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "PE",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=3CRCAAAAYAAJ&hl=&printsec=frontcover&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "NXxPzQEACAAJ",
#       "etag": "jMfxH7SKHyY",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/NXxPzQEACAAJ",
#       "volumeInfo": {
#         "title": "El caballero carmelo",
#         "publishedDate": "1940",
#         "industryIdentifiers": [
#           {
#             "type": "OTHER",
#             "identifier": "OCLC:1137283345"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 116,
#         "printType": "BOOK",
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "language": "es",
#         "previewLink": "http://books.google.com.pe/books?id=NXxPzQEACAAJ&dq=el+caballero+carmelo&hl=&cd=5&source=gbs_api",
#         "infoLink": "http://books.google.com.pe/books?id=NXxPzQEACAAJ&dq=el+caballero+carmelo&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/El_caballero_carmelo.html?hl=&id=NXxPzQEACAAJ"
#       },
#       "saleInfo": {
#         "country": "PE",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "PE",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=NXxPzQEACAAJ&hl=&printsec=frontcover&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "rVFTAAAAMAAJ",
#       "etag": "E+1VVdFdNcU",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/rVFTAAAAMAAJ",
#       "volumeInfo": {
#         "title": "El caballero Carmelo",
#         "subtitle": "otros cuentos, poemas y ensayos",
#         "authors": [
#           "Abraham Valdelomar"
#         ],
#         "publishedDate": "1969",
#         "industryIdentifiers": [
#           {
#             "type": "OTHER",
#             "identifier": "UTEXAS:059173024589979"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 116,
#         "printType": "BOOK",
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "0.1.2.0.preview.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=rVFTAAAAMAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=rVFTAAAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "es",
#         "previewLink": "http://books.google.com.pe/books?id=rVFTAAAAMAAJ&q=el+caballero+carmelo&dq=el+caballero+carmelo&hl=&cd=6&source=gbs_api",
#         "infoLink": "http://books.google.com.pe/books?id=rVFTAAAAMAAJ&dq=el+caballero+carmelo&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/El_caballero_Carmelo.html?hl=&id=rVFTAAAAMAAJ"
#       },
#       "saleInfo": {
#         "country": "PE",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "PE",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=rVFTAAAAMAAJ&hl=&printsec=frontcover&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "8mucGQAACAAJ",
#       "etag": "p7TXQKZ6z/M",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/8mucGQAACAAJ",
#       "volumeInfo": {
#         "title": "El caballero carmelo y otro cuentos",
#         "authors": [
#           "Abraham Valdelomar"
#         ],
#         "publishedDate": "2004",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "9972340961"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9789972340963"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 212,
#         "printType": "BOOK",
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "language": "es",
#         "previewLink": "http://books.google.com.pe/books?id=8mucGQAACAAJ&dq=el+caballero+carmelo&hl=&cd=7&source=gbs_api",
#         "infoLink": "http://books.google.com.pe/books?id=8mucGQAACAAJ&dq=el+caballero+carmelo&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/El_caballero_carmelo_y_otro_cuentos.html?hl=&id=8mucGQAACAAJ"
#       },
#       "saleInfo": {
#         "country": "PE",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "PE",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=8mucGQAACAAJ&hl=&printsec=frontcover&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "VlFTAAAAMAAJ",
#       "etag": "B36c08S0hcE",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/VlFTAAAAMAAJ",
#       "volumeInfo": {
#         "title": "El caballero Carmelo",
#         "subtitle": "cuentos ...",
#         "authors": [
#           "Abraham Valdelomar"
#         ],
#         "publishedDate": "1918",
#         "industryIdentifiers": [
#           {
#             "type": "OTHER",
#             "identifier": "UTEXAS:059173024589935"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 228,
#         "printType": "BOOK",
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "0.1.3.0.preview.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=VlFTAAAAMAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=VlFTAAAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "es",
#         "previewLink": "http://books.google.com.pe/books?id=VlFTAAAAMAAJ&q=el+caballero+carmelo&dq=el+caballero+carmelo&hl=&cd=8&source=gbs_api",
#         "infoLink": "http://books.google.com.pe/books?id=VlFTAAAAMAAJ&dq=el+caballero+carmelo&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/El_caballero_Carmelo.html?hl=&id=VlFTAAAAMAAJ"
#       },
#       "saleInfo": {
#         "country": "PE",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "PE",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=VlFTAAAAMAAJ&hl=&printsec=frontcover&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "RrycDAEACAAJ",
#       "etag": "bjvMQcPR/rk",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/RrycDAEACAAJ",
#       "volumeInfo": {
#         "title": "El Caballero Carmelo y otros cuentos criollos",
#         "authors": [
#           "Abraham Valdelomar"
#         ],
#         "publishedDate": "2009",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "9972400182"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9789972400186"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 153,
#         "printType": "BOOK",
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "language": "es",
#         "previewLink": "http://books.google.com.pe/books?id=RrycDAEACAAJ&dq=el+caballero+carmelo&hl=&cd=9&source=gbs_api",
#         "infoLink": "http://books.google.com.pe/books?id=RrycDAEACAAJ&dq=el+caballero+carmelo&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/El_Caballero_Carmelo_y_otros_cuentos_cri.html?hl=&id=RrycDAEACAAJ"
#       },
#       "saleInfo": {
#         "country": "PE",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "PE",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=RrycDAEACAAJ&hl=&printsec=frontcover&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "LoBezQEACAAJ",
#       "etag": "tmT/V/Ir3Pw",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/LoBezQEACAAJ",
#       "volumeInfo": {
#         "title": "Yerba santa",
#         "authors": [
#           "Abraham Valdelomar"
#         ],
#         "publishedDate": "2020-02-06",
#         "description": "Pedro Abraham Valdelomar Pinto (Ica, 27 de abril1 de 1888 - Ayacucho, 3 de noviembre de 1919) fue un narrador, poeta, periodista, ensayista y dramaturgo peruano. Es considerado uno de los principales cuentistas del Perú, junto con Julio Ramón Ribeyro. Abraham Valdelomar fue un escritor completo pues abarcó prácticamente todos los géneros literarios conocidos. Sin embargo, lo mejor de su creación ficticia se concentra en el campo de la narrativa cuentística. Sus cuentos se publicaron en revistas y periódicos de la época, y él mismo los organizó en dos libros: El caballero Carmelo (Lima, 1918) y Los hijos del Sol (póstumo, Lima,1921). En ellos se encuentran los primeros testimonios del cuento neocriollo peruano, de rasgos postmodernistas, que marcaron el punto de partida de la narrativa moderna del Perú. En el cuento El caballero Carmelo, que da nombre a su primer libro de cuentos, se utiliza un vocabulario arcaico y una retórica propia de las novelas de caballerías para narrar la triste historia de un gallo de pelea, relato nostálgico ambientado en Pisco, durante la infancia del autor. En Los hijos del Sol, busca su inspiración en el pasado histórico del Perú, remontándose a la época de los incas.Este libro electrónico presenta Yerba santa, de Abraham Valdelomar, en texto completo. Un índice interactivo permite acceder directamente al capítulo seleccionado.",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9798610093055"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 28,
#         "printType": "BOOK",
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=LoBezQEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=LoBezQEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "es",
#         "previewLink": "http://books.google.com.pe/books?id=LoBezQEACAAJ&dq=el+caballero+carmelo&hl=&cd=10&source=gbs_api",
#         "infoLink": "http://books.google.com.pe/books?id=LoBezQEACAAJ&dq=el+caballero+carmelo&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Yerba_santa.html?hl=&id=LoBezQEACAAJ"
#       },
#       "saleInfo": {
#         "country": "PE",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "PE",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=LoBezQEACAAJ&hl=&printsec=frontcover&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "Pedro Abraham Valdelomar Pinto (Ica, 27 de abril1 de 1888 - Ayacucho, 3 de noviembre de 1919) fue un narrador, poeta, periodista, ensayista y dramaturgo peruano."
#       }
#     }
#   ]
# }

# %%
book = result.json() #los resultados que se obtuvieron lo transformamos en json para trabajar de una manera más amigable
print(book.keys()) # Esto es para saber cuales son los elemntos principales
#Luego de esto analizamos cual es el elemento que tiene información más interesante y que deseamos obtener
#En nuestro caso la variable que presenta más información es: "items"
# Out:
# dict_keys(['kind', 'totalItems', 'items'])

# %%
items = book["items"] #obtenemos la información de items
print(items)#Imprimimos ...
# Out:
# [{'kind': 'books#volume', 'id': '6RNNAgAAQBAJ', 'etag': 'IDoUCQBdK7w', 'selfLink': 'https://www.googleapis.com/books/v1/volumes/6RNNAgAAQBAJ', 'volumeInfo': {'title': 'El Caballero Carmelo y otros cuentos', 'subtitle': '', 'authors': ['Abraham Valdelomar'], 'publisher': 'eLibros Editorial', 'publishedDate': '2011-09-15', 'description': 'El Caballero Carmelo, colección de cuatro cuentos de Abraham Valdelomar publicada en 1918, se nos muestra tan rica y diversa que en cada uno de los relatos nos sumergimos en tonos narrativos diferentes, a veces opuestos, todos de una emotividad sorprendente. Iniciando por el suspenso desde la óptica de un niño que asiste, en una narración emocionante, al combate a muerte de su gallo; la melancolía y el ridículo, al mismo tiempo, de la historia de un triste hombre que tiene en un árbol del mismo nombre y edad a su alma gemela; la ternura y el drama del amor de un niño por su amiguita la estrella del circo; e incluso, nuevamente desde el punto de vista de un asustado chico –miedo en el que el lector también se involucra– que presencia apariciones de una mujer extraña, una especie de visión muy personal de lo religioso. Todo lo anterior nos da como resultado un libro ágil y que rompe por su sencillez de estilo y temática con la moda literaria precedente, tan española y artificial. Esta edición incluye biografía del autor y prefacio con contexto histórico y literario de la obra.', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9789588732237'}, {'type': 'ISBN_10', 'identifier': '9588732239'}], 'readingModes': {'text': True, 'image': False}, 'pageCount': 96, 'printType': 'BOOK', 'categories': ['Fiction'], 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': True, 'contentVersion': 'preview-1.0.0', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=6RNNAgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=6RNNAgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'es', 'previewLink': 'http://books.google.com.pe/books?id=6RNNAgAAQBAJ&printsec=frontcover&dq=el+caballero+carmelo&hl=&cd=1&source=gbs_api', 'infoLink': 'https://play.google.com/store/books/details?id=6RNNAgAAQBAJ&source=gbs_api', 'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=6RNNAgAAQBAJ'}, 'saleInfo': {'country': 'PE', 'saleability': 'FOR_SALE', 'isEbook': True, 'listPrice': {'amount': 7.87, 'currencyCode': 'PEN'}, 'retailPrice': {'amount': 7.87, 'currencyCode': 'PEN'}, 'buyLink': 'https://play.google.com/store/books/details?id=6RNNAgAAQBAJ&rdid=book-6RNNAgAAQBAJ&rdot=1&source=gbs_api', 'offers': [{'finskyOfferType': 1, 'listPrice': {'amountInMicros': 7870000, 'currencyCode': 'PEN'}, 'retailPrice': {'amountInMicros': 7870000, 'currencyCode': 'PEN'}}]}, 'accessInfo': {'country': 'PE', 'viewability': 'PARTIAL', 'embeddable': True, 'publicDomain': False, 'textToSpeechPermission': 'ALLOWED', 'epub': {'isAvailable': True, 'acsTokenLink': 'http://books.google.com.pe/books/download/El_Caballero_Carmelo_y_otros_cuentos-sample-epub.acsm?id=6RNNAgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'}, 'pdf': {'isAvailable': False}, 'webReaderLink': 'http://play.google.com/books/reader?id=6RNNAgAAQBAJ&hl=&printsec=frontcover&source=gbs_api', 'accessViewStatus': 'SAMPLE', 'quoteSharingAllowed': False}, 'searchInfo': {'textSnippet': 'El Caballero Carmelo, colección de cuatro cuentos de Abraham Valdelomar publicada en 1918, se nos muestra tan rica y diversa que en cada uno de los relatos nos sumergimos en tonos narrativos diferentes, a veces opuestos, todos de una ...'}}, {'kind': 'books#volume', 'id': 'YTw2AAAAIAAJ', 'etag': 'eB9W9v4tmLI', 'selfLink': 'https://www.googleapis.com/books/v1/volumes/YTw2AAAAIAAJ', 'volumeInfo': {'title': 'Perfil y entraña de El caballero Carmelo', 'subtitle':  ...

# %%
#Vamos a encodificar y luego decodificar debido a que hay información dentro de otra.
encoded = json.dumps(items)
decoded = json.loads(encoded)
print(decoded[0]) #Decoded es una lista y esta presenta solo 10 resultados(que son de la primera pestaña), por lo tanto
#Nos arrojara cada resultado especifico que querramos
# Out:
# {'kind': 'books#volume', 'id': '6RNNAgAAQBAJ', 'etag': 'IDoUCQBdK7w', 'selfLink': 'https://www.googleapis.com/books/v1/volumes/6RNNAgAAQBAJ', 'volumeInfo': {'title': 'El Caballero Carmelo y otros cuentos', 'subtitle': '', 'authors': ['Abraham Valdelomar'], 'publisher': 'eLibros Editorial', 'publishedDate': '2011-09-15', 'description': 'El Caballero Carmelo, colección de cuatro cuentos de Abraham Valdelomar publicada en 1918, se nos muestra tan rica y diversa que en cada uno de los relatos nos sumergimos en tonos narrativos diferentes, a veces opuestos, todos de una emotividad sorprendente. Iniciando por el suspenso desde la óptica de un niño que asiste, en una narración emocionante, al combate a muerte de su gallo; la melancolía y el ridículo, al mismo tiempo, de la historia de un triste hombre que tiene en un árbol del mismo nombre y edad a su alma gemela; la ternura y el drama del amor de un niño por su amiguita la estrella del circo; e incluso, nuevamente desde el punto de vista de un asustado chico –miedo en el que el lector también se involucra– que presencia apariciones de una mujer extraña, una especie de visión muy personal de lo religioso. Todo lo anterior nos da como resultado un libro ágil y que rompe por su sencillez de estilo y temática con la moda literaria precedente, tan española y artificial. Esta edición incluye biografía del autor y prefacio con contexto histórico y literario de la obra.', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9789588732237'}, {'type': 'ISBN_10', 'identifier': '9588732239'}], 'readingModes': {'text': True, 'image': False}, 'pageCount': 96, 'printType': 'BOOK', 'categories': ['Fiction'], 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': True, 'contentVersion': 'preview-1.0.0', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=6RNNAgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=6RNNAgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'es', 'previewLink': 'http://books.google.com.pe/books?id=6RNNAgAAQBAJ&printsec=frontcover&dq=el+caballero+carmelo&hl=&cd=1&source=gbs_api', 'infoLink': 'https://play.google.com/store/books/details?id=6RNNAgAAQBAJ&source=gbs_api', 'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=6RNNAgAAQBAJ'}, 'saleInfo': {'country': 'PE', 'saleability': 'FOR_SALE', 'isEbook': True, 'listPrice': {'amount': 7.87, 'currencyCode': 'PEN'}, 'retailPrice': {'amount': 7.87, 'currencyCode': 'PEN'}, 'buyLink': 'https://play.google.com/store/books/details?id=6RNNAgAAQBAJ&rdid=book-6RNNAgAAQBAJ&rdot=1&source=gbs_api', 'offers': [{'finskyOfferType': 1, 'listPrice': {'amountInMicros': 7870000, 'currencyCode': 'PEN'}, 'retailPrice': {'amountInMicros': 7870000, 'currencyCode': 'PEN'}}]}, 'accessInfo': {'country': 'PE', 'viewability': 'PARTIAL', 'embeddable': True, 'publicDomain': False, 'textToSpeechPermission': 'ALLOWED', 'epub': {'isAvailable': True, 'acsTokenLink': 'http://books.google.com.pe/books/download/El_Caballero_Carmelo_y_otros_cuentos-sample-epub.acsm?id=6RNNAgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'}, 'pdf': {'isAvailable': False}, 'webReaderLink': 'http://play.google.com/books/reader?id=6RNNAgAAQBAJ&hl=&printsec=frontcover&source=gbs_api', 'accessViewStatus': 'SAMPLE', 'quoteSharingAllowed': False}, 'searchInfo': {'textSnippet': 'El Caballero Carmelo, colección de cuatro cuentos de Abraham Valdelomar publicada en 1918, se nos muestra tan rica y diversa que en cada uno de los relatos nos sumergimos en tonos narrativos diferentes, a veces opuestos, todos de una ...'}}

# %%
#Como nos podemos percatar, hay llaves dentro de la lista que aún tienen más información y podemos acceder a ellas de la
#siguiente manera...
print(decoded[0]["volumeInfo"]) #Con esto podemos ver que es l que hay dentro de "volumeInfo"
# Out:
# {'title': 'El Caballero Carmelo y otros cuentos', 'subtitle': '', 'authors': ['Abraham Valdelomar'], 'publisher': 'eLibros Editorial', 'publishedDate': '2011-09-15', 'description': 'El Caballero Carmelo, colección de cuatro cuentos de Abraham Valdelomar publicada en 1918, se nos muestra tan rica y diversa que en cada uno de los relatos nos sumergimos en tonos narrativos diferentes, a veces opuestos, todos de una emotividad sorprendente. Iniciando por el suspenso desde la óptica de un niño que asiste, en una narración emocionante, al combate a muerte de su gallo; la melancolía y el ridículo, al mismo tiempo, de la historia de un triste hombre que tiene en un árbol del mismo nombre y edad a su alma gemela; la ternura y el drama del amor de un niño por su amiguita la estrella del circo; e incluso, nuevamente desde el punto de vista de un asustado chico –miedo en el que el lector también se involucra– que presencia apariciones de una mujer extraña, una especie de visión muy personal de lo religioso. Todo lo anterior nos da como resultado un libro ágil y que rompe por su sencillez de estilo y temática con la moda literaria precedente, tan española y artificial. Esta edición incluye biografía del autor y prefacio con contexto histórico y literario de la obra.', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9789588732237'}, {'type': 'ISBN_10', 'identifier': '9588732239'}], 'readingModes': {'text': True, 'image': False}, 'pageCount': 96, 'printType': 'BOOK', 'categories': ['Fiction'], 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': True, 'contentVersion': 'preview-1.0.0', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=6RNNAgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=6RNNAgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'es', 'previewLink': 'http://books.google.com.pe/books?id=6RNNAgAAQBAJ&printsec=frontcover&dq=el+caballero+carmelo&hl=&cd=1&source=gbs_api', 'infoLink': 'https://play.google.com/store/books/details?id=6RNNAgAAQBAJ&source=gbs_api', 'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=6RNNAgAAQBAJ'}

# %%
#Como podemos apreciar hay más llaves dentro de esta llave y lo unico que tenemos que hacer es seguir agregando corchetes y
#y dentro de estos colocar la información que requerimos
#Pero en esta ocasión nosotros deseamos extarer el resumen que esta con el nombre "description"
print(decoded[0]["volumeInfo"]["description"])
# Out:
# El Caballero Carmelo, colección de cuatro cuentos de Abraham Valdelomar publicada en 1918, se nos muestra tan rica y diversa que en cada uno de los relatos nos sumergimos en tonos narrativos diferentes, a veces opuestos, todos de una emotividad sorprendente. Iniciando por el suspenso desde la óptica de un niño que asiste, en una narración emocionante, al combate a muerte de su gallo; la melancolía y el ridículo, al mismo tiempo, de la historia de un triste hombre que tiene en un árbol del mismo nombre y edad a su alma gemela; la ternura y el drama del amor de un niño por su amiguita la estrella del circo; e incluso, nuevamente desde el punto de vista de un asustado chico –miedo en el que el lector también se involucra– que presencia apariciones de una mujer extraña, una especie de visión muy personal de lo religioso. Todo lo anterior nos da como resultado un libro ágil y que rompe por su sencillez de estilo y temática con la moda literaria precedente, tan española y artificial. Esta edición incluye biografía del autor y prefacio con contexto histórico y literario de la obra.

# %%
#De esta manera podemos acceder a la api de google books y extraer la información que nos parezca conveniente.
#Esta api es publica, por lo que no es necesario obterner una key, loguearse, etc.

#Integrantes del grupo: 
#*Elian Jesus Ayala Castillo 20181144
#*Jhosep Palomino Bustinza 20191309
#*Romero Solano Juana Paola 20191313
#*Jorge CCollana Orosco 20191295


#Gracias :D
